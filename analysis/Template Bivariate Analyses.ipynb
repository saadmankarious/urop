# %%
import pandas as pd
import os

# Load in chunks for when you have a large CSV file
chunk_size = 500000  # This can be adjusted based on your memory on your machine
chunks = []
for chunk in pd.read_csv('~/code/urop/reddit/data/2019_output/ann-combined.csv', chunksize=chunk_size):
    chunks.append(chunk)  

data_sentence = pd.concat(chunks)

# Extract the class label from the first character of the 'tid' and create a new 'fraudulent' column
def extract_label(tid):
    if tid[0].isdigit():
        return int(tid[0])
    else:
        return None

data_sentence['fraudulent'] = data_sentence['tid'].astype(str).apply(extract_label)

# Drop rows where the fraudulent label could not be determined
fraud_sent = data_sentence.dropna(subset=['fraudulent'])

# Display the first few rows of the fraud_sent DataFrame
fraud_sent.head()
# Out:
#                           tid  sid  MLS   MLC   MLT  CpS  CpT  cTT   dCC  cCT  \
# 0  1_TwinkleMcFabulous_xg014s    0   26  6.50  13.0    4  2.0  0.0  0.25  0.5
# 1  1_TwinkleMcFabulous_xg014s    1    1  0.00   1.0    0  0.0  0.0  0.00  0.0
# 2  1_TwinkleMcFabulous_wiub0i    0   26  5.20  26.0    5  5.0  1.0  0.40  2.0
# 3  1_TwinkleMcFabulous_wiub0i    1   31  7.75  15.5    4  2.0  0.5  0.25  0.5
# 4  1_TwinkleMcFabulous_wb878p    0   22  5.50  11.0    4  2.0  0.5  0.50  1.0
#
#    ...  WF_Reddit  WF_Podcast  WF_TOTAL  CD_Podcast   CD_TV  CD_Reddit  \
# 0  ...     9.8142      8.6662   10.3114      7.6895  7.7033     7.3586
# 1  ...     0.0000      0.0000    0.0000      0.0000  0.0000     0.0000
# 2  ...    10.2036      8.8894   10.6714      8.0315  8.2333     7.6953
# 3  ...    10.3798      9.2728   10.8583      8.3372  8.2661     7.9107
# 4  ...     9.8744      8.8068   10.3546      7.7493  7.9091     7.4039
#
#     WP_TV  WP_Podcast  WP_Reddit  fraudulent
# 0  6.7356      5.9364     7.1347           1
# 1  0.0000      0.0000     0.0000           1
# 2  7.1395      6.2445     7.4719           1
# 3  7.1645      6.3989     7.6734           1
# 4  6.8340      5.9707     7.1932           1
#
# [5 rows x 407 columns]

# %%
# # here I had another df called "labels" with two columns: "tid" and "fraudulent", which I join with the original data to add the class labels 
# file_path = '/Users/daniel24/Documents/0_Exaia/Research/FraudDetection/Data/fake_job_labels.csv'  # Replace with your file path
# labels = pd.read_csv(file_path)
# fraud_sent = pd.merge(data_sentence, labels, on='tid', how='inner')

# %%
# so this how your CYMO data look like 
fraud_sent.head()
# Out:
#                           tid  sid  MLS   MLC   MLT  CpS  CpT  cTT   dCC  cCT  \
# 0  1_TwinkleMcFabulous_xg014s    0   26  6.50  13.0    4  2.0  0.0  0.25  0.5
# 1  1_TwinkleMcFabulous_xg014s    1    1  0.00   1.0    0  0.0  0.0  0.00  0.0
# 2  1_TwinkleMcFabulous_wiub0i    0   26  5.20  26.0    5  5.0  1.0  0.40  2.0
# 3  1_TwinkleMcFabulous_wiub0i    1   31  7.75  15.5    4  2.0  0.5  0.25  0.5
# 4  1_TwinkleMcFabulous_wb878p    0   22  5.50  11.0    4  2.0  0.5  0.50  1.0
#
#    ...  WF_Reddit  WF_Podcast  WF_TOTAL  CD_Podcast   CD_TV  CD_Reddit  \
# 0  ...     9.8142      8.6662   10.3114      7.6895  7.7033     7.3586
# 1  ...     0.0000      0.0000    0.0000      0.0000  0.0000     0.0000
# 2  ...    10.2036      8.8894   10.6714      8.0315  8.2333     7.6953
# 3  ...    10.3798      9.2728   10.8583      8.3372  8.2661     7.9107
# 4  ...     9.8744      8.8068   10.3546      7.7493  7.9091     7.4039
#
#     WP_TV  WP_Podcast  WP_Reddit  fraudulent
# 0  6.7356      5.9364     7.1347           1
# 1  0.0000      0.0000     0.0000           1
# 2  7.1395      6.2445     7.4719           1
# 3  7.1645      6.3989     7.6734           1
# 4  6.8340      5.9707     7.1932           1
#
# [5 rows x 407 columns]

# %%
# this is how your input data for the descriptive stats, the bivariate analyses (t-test + cohen's d) and the shallow machine learning models should look like 
# -> one row per userID, MHC, all averaged CYMO feature scores
data_tid = fraud_sent.groupby(['tid']).mean()
data_tid.drop(columns=['sid'], inplace=True)
# Move the 'sid' column to the front
columns = ['fraudulent'] + [col for col in data_tid if col != 'fraudulent']
data_tid = data_tid[columns]
data_tid.head()
# Out:
#                                                     fraudulent        MLS  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6                     0.0  11.714286
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r             0.0  10.333333
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe            0.0  13.500000
# 0_10s_gamerccxxi_General-Writing1764_1diizfy               0.0   8.333333
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...         0.0  16.000000
#
#                                                          MLC        MLT  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6              5.357143   6.857143
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r      5.000000   7.833333
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe     4.500000   6.750000
# 0_10s_gamerccxxi_General-Writing1764_1diizfy        4.833333   8.333333
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...  4.708325  10.500000
#
#                                                          CpS       CpT  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6              1.857143  1.000000
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r      2.333333  1.833333
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe     3.000000  1.500000
# 0_10s_gamerccxxi_General-Writing1764_1diizfy        1.666667  1.666667
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...  2.250000  1.500000
#
#                                                          cTT       dCC  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6              0.214286  0.285714
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r      0.500000  0.333333
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe     0.500000  0.333300
# 0_10s_gamerccxxi_General-Writing1764_1diizfy        0.666667  0.333333
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...  0.375000  0.166675
#
#                                                          cCT       CPC  ...  \
# tid                                                                     ...
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6              0.500000  0.250000  ...
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r      0.833333  0.111100  ...
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe     0.500000  0.333300  ...
# 0_10s_gamerccxxi_General-Writing1764_1diizfy        0.666667  0.000000  ...
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...  0.375000  0.041675  ...
#
#                                                        WF_TV  WF_Reddit  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6              7.564857   9.090400
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r      8.535967   9.626800
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe     8.953850  10.309350
# 0_10s_gamerccxxi_General-Writing1764_1diizfy        8.175967   8.990867
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...  6.154325   7.007325
#
#                                                     WF_Podcast   WF_TOTAL  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6                7.953114   9.542586
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r        8.761300  10.201633
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe       9.274550  10.810250
# 0_10s_gamerccxxi_General-Writing1764_1diizfy          8.231967   9.477500
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...    6.202000   7.364300
#
#                                                     CD_Podcast     CD_TV  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6                7.056743  6.790729
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r        7.675800  7.501933
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe       8.004900  7.821200
# 0_10s_gamerccxxi_General-Writing1764_1diizfy          7.090600  7.124700
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...    5.482075  5.467700
#
#                                                     CD_Reddit     WP_TV  \
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6               6.791971  5.883471
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r       7.120467  6.490067
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe      7.618350  6.694350
# 0_10s_gamerccxxi_General-Writing1764_1diizfy         6.717700  6.077233
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...   5.320375  4.743350
#
#                                                     WP_Podcast  WP_Reddit
# tid
# 0_0xPolygon_jnpln_ChillCaptain_125u6y6                5.378414   6.560543
# 0_100pushups_Backupaccount524_JJWentMMA_4rg22r        5.865433   6.895300
# 0_100thieves_MeringueWhich9353_Keito1000_jxdaxe       6.077200   7.361100
# 0_10s_gamerccxxi_General-Writing1764_1diizfy          5.362367   6.517700
# 0_13sentinels_ichigo_wildblossom_Fun-Wash-8858_...    4.249550   5.167050
#
# [5 rows x 405 columns]

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_ind
from statsmodels.stats.multitest import multipletests
from math import sqrt

# List of numerical columns to test
numerical_columns = fraud_sent.columns.drop(['tid', 'sid', 'fraudulent'])

# Separate data into fraudulent and non-fraudulent
fraudulent_data = fraud_sent[fraud_sent['fraudulent'] == 1]
non_fraudulent_data = fraud_sent[fraud_sent['fraudulent'] == 0]

# Perform t-tests
t_stat, p_values = [], []
for column in numerical_columns:
    t_stat_current, p_value_current = ttest_ind(fraudulent_data[column], non_fraudulent_data[column], nan_policy='omit')
    t_stat.append(t_stat_current)
    p_values.append(p_value_current)

# Apply Bonferroni correction
_, p_values_corrected, _, _ = multipletests(p_values, alpha=0.05, method='bonferroni')

# Calculate Cohen's d
cohens_d = []
for column in numerical_columns:
    mean_fraud = fraudulent_data[column].mean()
    mean_non_fraud = non_fraudulent_data[column].mean()
    std_fraud = fraudulent_data[column].std()
    std_non_fraud = non_fraudulent_data[column].std()
    pooled_std = sqrt((std_fraud**2 + std_non_fraud**2) / 2)
    cohens_d.append((mean_fraud - mean_non_fraud) / pooled_std)

# Create a DataFrame to display results
results_df = pd.DataFrame({
    'Feature': numerical_columns,
    'T-Statistic': t_stat,
    'P-Value (Corrected)': p_values_corrected,
    'Cohen\'s d': cohens_d
})

# Order the results by increasing p-value
results_df = results_df.sort_values(by="Cohen's d", ascending=False)

# Display the ordered results
# print(results_df)

# %%
# Display the results
results_df
# Out:
#                                      Feature  T-Statistic  \
# 85        adjacent-overlap.binary-2-all-sent   198.290189
# 97         adjacent-overlap.binary-2-fw-sent   191.639501
# 133  adjacent-overlap.binary-2-argument-sent   182.716766
# 127   adjacent-overlap.binary-2-pronoun-sent   170.277912
# 95                adjacent-overlap.2-fw-sent   147.019505
# ..                                       ...          ...
# 123    adjacent-overlap.pronoun-sent-div-seg   -61.177578
# 87          adjacent-overlap.cw-sent-div-seg   -71.037269
# 129   adjacent-overlap.argument-sent-div-seg   -77.708958
# 93          adjacent-overlap.fw-sent-div-seg   -83.177945
# 81         adjacent-overlap.all-sent-div-seg   -88.355972
#
#      P-Value (Corrected)  Cohen's d
# 85                   0.0   0.661025
# 97                   0.0   0.646864
# 133                  0.0   0.632225
# 127                  0.0   0.607849
# 95                   0.0   0.580267
# ..                   ...        ...
# 123                  0.0  -0.209434
# 87                   0.0  -0.237600
# 129                  0.0  -0.262616
# 93                   0.0  -0.286229
# 81                   0.0  -0.301774
#
# [404 rows x 4 columns]
